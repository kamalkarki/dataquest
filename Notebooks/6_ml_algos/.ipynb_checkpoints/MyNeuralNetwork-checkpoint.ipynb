# %%
# starting the neural network in last time I have to finish it.
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
iris = pd.read_csv('/home/kamlesh/AnacondaProjects/Dataquest/Data/iris.csv')

# %%
iris.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width          species
# 0           7.0          3.2           4.7          1.4  Iris-versicolor
# 1           6.4          3.2           4.5          1.5  Iris-versicolor
# 2           6.9          3.1           4.9          1.5  Iris-versicolor
# 3           5.5          2.3           4.0          1.3  Iris-versicolor
# 4           6.5          2.8           4.6          1.5  Iris-versicolor

# %%
iris.dtypes
# Out:
# sepal_length    float64
# sepal_width     float64
# petal_length    float64
# petal_width     float64
# species          object
# dtype: object

# %%
iris['species'].unique() # only two types of species in this iris data set
# Out:
# array(['Iris-versicolor', 'Iris-virginica'], dtype=object)

# %%
#overview of the data set
iris.describe()
# Out:
#        sepal_length  sepal_width  petal_length  petal_width
# count    100.000000   100.000000    100.000000   100.000000
# mean       6.262000     2.872000      4.906000     1.676000
# std        0.662834     0.332751      0.825578     0.424769
# min        4.900000     2.000000      3.000000     1.000000
# 25%        5.800000     2.700000      4.375000     1.300000
# 50%        6.300000     2.900000      4.900000     1.600000
# 75%        6.700000     3.025000      5.525000     2.000000
# max        7.900000     3.800000      6.900000     2.500000

# %%
# for visual representation use Historgram. Other visual representations 
iris.hist()
plt.show()

# %% [markdown]
# Now why we need to use Neural network and why we are going to use it ?
# Write down that in detail.

# %% [markdown]
# # Visualizations

# %%
# box and whisker plots
iris.plot(kind='box', sharex=False, sharey=False)
plt.show()

# %%
# boxplot on each feature split out by species
iris.boxplot(by='species',figsize=(10,10))
plt.show()

# %%
# violinplots on petal-length for each species
sns.violinplot(data = iris,x="species", y="petal_length")
plt.show()

# %%
sns.pairplot(iris,hue = 'species',diag_kind= 'kde')
plt.show()

# %%
#pp = sns.pairplot( iris, hue='species', size=1.8, aspect=1.8, palette={"Iris-versicolor": "#FF2334", "Iris-virginica": "#AFE688"},)
#fig = pp.fig 
##fig.subplots_adjust(top=0.93, wspace=0.3)
#t = fig.suptitle('Pairwise plots for 4 attributs', fontsize=18)
#plt.show()

# %%
# Visualizing 3-D numeric data with Scatter Plots
# length, breadth and depth
from mpl_toolkits.mplot3d import Axes3D
fig = plt.figure(figsize=(8, 6))
ax = fig.add_subplot(111, projection='3d')

xs = iris['petal_length']
ys = iris['petal_width']
zs = iris['sepal_length']
ax.scatter(xs, ys, zs, s=50, alpha=0.6, edgecolors='w')

ax.set_xlabel('Petal_length')
ax.set_ylabel('Petal_width')
ax.set_zlabel('Sepal_length')
plt.show()

# %% [markdown]
# ### From the visual representation , there is  non linearity in the data, explore more abut this and thats why we are using the neural network
#
# - Non linearity in the data, where this is not a linear function to seperate the data of different classes.
# - ???? or what else could it be?

# %% [markdown]
# - Write a function called sigmoid_activation with inputs x a feature vector and theta a parameter vector of the same length to implement the sigmoid activation function.
# -        Assign the value of sigmoid_activation(x0, theta_init) to a1. a1 should be a scaler

# %%
# initiating weight values
z = np.asarray([[9, 5, 4]])
y = np.asarray([[-1, 2, 4]])

# np.dot is used for matrix multiplication
# z is 1x3 and y is 1x3,  z * y.T is then 1x1
print(np.dot(z,y.T))

# Variables to test sigmoid_activation
iris["ones"] = np.ones(iris.shape[0])
X = iris[['ones', 'sepal_length', 'sepal_width', 'petal_length', 'petal_width']].values
y = (iris.species == 'Iris-versicolor').values.astype(int)

# The first observation
x0 = X[0]

# Initialize thetas randomly 
theta_init = np.random.normal(0,0.01,size=(5,1))
def sigmoid_activation( x,theta ):
    output = np.dot(x.T,theta)
    a1 = 1/1+ np.exp(-output)
    return a1
    
a1 = sigmoid_activation( x0,theta_init )
# Out:
# [[17]]

# %%
np.array(x0)
# Out:
# array([ 1. ,  7. ,  3.2,  4.7,  1.4])

# %% [markdown]
# https://stats.stackexchange.com/questions/278771/how-is-the-cost-function-from-logistic-regression-derivated
#
# https://math.stackexchange.com/questions/477207/derivative-of-cost-function-for-logistic-regression/1438744
#
# http://www.ai.mit.edu/courses/6.892/lecture8-html/sld015.
#
# https://www.google.com/url?sa=t&rct=j&q=&esrc=s&source=web&cd=6&cad=rja&uact=8&ved=0ahUKEwjt_NTf0_bbAhUV148KHZ3AAkMQFghfMAU&url=https%3A%2F%2Fwww.coursera.org%2Flecture%2Fneural-networks-deep-learning%2Flogistic-regression-gradient-descent-5sdh6&usg=AOvVaw2XuQjODQYP0Ui1obOpOyAp

# %%
print( theta_init.shape )
# Out:
# (5, 1)

# %%
print( theta_init)
# Out:
# [[ 0.01686397]
#  [-0.00028287]
#  [ 0.0109579 ]
#  [-0.00561015]
#  [-0.00340029]]

# %%
grads = np.zeros(theta_init.shape)

# %%
grads
# Out:
# array([[ 0.],
#        [ 0.],
#        [ 0.],
#        [ 0.],
#        [ 0.]])

# %% [markdown]
# Write a function, singlecost(), that can compute the cost from just a single observation.
#
#     This function should use input features X, targets y, and parameters theta to compute the cost function.
#     Assign the cost of variables x0, y0, and theta_init to variable first_cost.

# %%
# First observation's features and target
x0 = X[0]
y0 = y[0]
#print(type(x0))
#Initialize parameters, we have 5 units and just 1 layer
theta_init = np.random.normal(0,0.01,size=(5,1))

def singlecost(x,y,theta):
    output = np.dot(x.T,theta)
    a1 = 1/(1+ np.exp(-output) ) # sigmoid activation
    # a1 s the value, now check it with the original value and 
    #find the cost function
    result = -( y * np.log(a1) + (1-y) * np.log( 1 - a1)) 
    return result
first_cost = singlecost( x0, y0, theta_init )
print(first_cost)
# Out:
# [ 0.67871024]

# %% [markdown]
# Compute the average gradients over each observation in X and corresponding target y with the initialized parameters theta_init.
#
#     Assign the average gradients to variable grads.

# %%
# Initialize parameters
theta_init = np.random.normal(0,0.01,size=(5,1))

# Store the updates into this array
grads = np.zeros(theta_init.shape)

# Number of observations 
n = X.shape[0]
for j, value in enumerate(X):
    #computing sigmoid_activation
    h = sigmoid_activation( value, theta_init )
    # the derivative
    #delta = ( h - y[j] ) * value
    delta = (y[j]-h) * h * (1-h) * value
    #summation
    grads += delta[:,np.newaxis]/ X.shape[0]
grads
# Out:
# array([[  2.7407474 ],
#        [ 17.43062745],
#        [  7.95909829],
#        [ 13.98656893],
#        [  4.89077873]])

# %% [markdown]
# ### Now we are going to write the code for derivation of logistic regression

# %% [markdown]
#     while (number_of_iterations < max_iterations and (prev_cost - cost) > convergence_thres )
#     {
#              update paramaters
#              get new cost
#             repeat
#     }

# %%
## two layer network

theta_init = np.random.normal(0,0.01,size=(5,1))

# set a learning rate
learning_rate = 0.1
# maximum number of iterations for gradient descent
maxepochs = 10000     
# costs convergence threshold, ie. (prevcost - cost) > convergence_thres
convergence_thres = 0.0001  

def learn(X, y, theta, learning_rate, maxepochs, convergence_thres):
    costs = []
    cost = singlecost(X, y, theta)  # compute initial cost
    costprev = cost + convergence_thres + 0.01  # set an inital costprev to past while loop
    counter = 0  # add a counter
    # Loop through until convergence
    for counter in range(maxepochs):
        grads = np.zeros(theta.shape)
        for j, obs in enumerate(X):
            h = sigmoid_activation(obs, theta)   # Compute activation
            delta = (y[j]-h) * h * (1-h) * obs   # Get delta
            #delta = (h - y[j]) * obs
            grads += delta[:,np.newaxis]/X.shape[0]  # accumulate
        
        # update parameters 
        theta += grads * learning_rate
        costprev = cost  # store prev cost
        cost = singlecost(X, y, theta) # compute new cost
        costs.append(cost)
        if np.abs(costprev-cost) < convergence_thres:
            break
        
    plt.plot(costs)
    plt.title("Convergence of the Cost Function")
    plt.ylabel("J($\Theta$)")
    plt.xlabel("Iteration")
    plt.show()
    return theta
        
theta = learn(X, y, theta_init, learning_rate, maxepochs, convergence_thres)
print(theta)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-32-6c706c292929> in <module>()
#      39     return theta
#      40
# ---> 41 theta = learn(X, y, theta_init, learning_rate, maxepochs, convergence_thres)
#      42 print(theta)
#
# <ipython-input-32-6c706c292929> in learn(X, y, theta, learning_rate, maxepochs, convergence_thres)
#      12 def learn(X, y, theta, learning_rate, maxepochs, convergence_thres):
#      13     costs = []
# ---> 14     cost = singlecost(X, y, theta)  # compute initial cost
#      15     costprev = cost + convergence_thres + 0.01  # set an inital costprev to past while loop
#      16     counter = 0  # add a counter
#
# <ipython-input-28-8176bd019894> in singlecost(x, y, theta)
#       7
#       8 def singlecost(x,y,theta):
# ----> 9     output = np.dot(x.T,theta)
#      10     a1 = 1/(1+ np.exp(-output) ) # sigmoid activation
#      11     # a1 s the value, now check it with the original value and
#
# ValueError: shapes (5,100) and (5,1) not aligned: 100 (dim 1) != 5 (dim 0)

# %%
theta0_init = np.random.normal(0,0.01,size=(5,4))
theta1_init = np.random.normal(0,0.01,size=(5,1))

def feedforward(X, theta0, theta1):
    # feedforward to the first layer
    a1 = sigmoid_activation(X.T, theta0).T
    # add a column of ones for bias term
    a1 = np.column_stack([np.ones(a1.shape[0]), a1])
    # activation units are then inputted to the output layer
    out = sigmoid_activation(a1.T, theta1)
    return out

h = feedforward(X, theta0_init, theta1_init)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-33-0fdb68f3ab8e> in <module>()
#      11     return out
#      12
# ---> 13 h = feedforward(X, theta0_init, theta1_init)
#
# <ipython-input-33-0fdb68f3ab8e> in feedforward(X, theta0, theta1)
#       8     a1 = np.column_stack([np.ones(a1.shape[0]), a1])
#       9     # activation units are then inputted to the output layer
# ---> 10     out = sigmoid_activation(a1.T, theta1)
#      11     return out
#      12
#
# <ipython-input-20-3639b61e3cdf> in sigmoid_activation(x, theta)
#      16
#      17 def sigmoid_activation( x,theta ):
# ---> 18     output = np.dot(x.T,theta)
#      19     h = 1/1+ np.exp(-output)
#      20     return h
#
# ValueError: shapes (4,101) and (5,1) not aligned: 101 (dim 1) != 5 (dim 0)

# %%
# X and y are in memory and should be used as inputs to multiplecost()

theta0_init = np.random.normal(0,0.01,size=(5,4))
theta1_init = np.random.normal(0,0.01,size=(5,1))

# X and y are in memory and should be used as inputs to multiplecost()
def multiplecost(X, y, theta0, theta1):
    # feed through network
    h = feedforward(X, theta0, theta1) 
    # compute error
    inner = y * np.log(h) + (1-y) * np.log(1-h)
    # negative of average error
    return -np.mean(inner)

c = multiplecost(X, y, theta0_init, theta1_init)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-34-f139b807a6e0> in <module>()
#      14     return -np.mean(inner)
#      15
# ---> 16 c = multiplecost(X, y, theta0_init, theta1_init)
#
# <ipython-input-34-f139b807a6e0> in multiplecost(X, y, theta0, theta1)
#       8 def multiplecost(X, y, theta0, theta1):
#       9     # feed through network
# ---> 10     h = feedforward(X, theta0, theta1)
#      11     # compute error
#      12     inner = y * np.log(h) + (1-y) * np.log(1-h)
#
# <ipython-input-33-0fdb68f3ab8e> in feedforward(X, theta0, theta1)
#       8     a1 = np.column_stack([np.ones(a1.shape[0]), a1])
#       9     # activation units are then inputted to the output layer
# ---> 10     out = sigmoid_activation(a1.T, theta1)
#      11     return out
#      12
#
# <ipython-input-20-3639b61e3cdf> in sigmoid_activation(x, theta)
#      16
#      17 def sigmoid_activation( x,theta ):
# ---> 18     output = np.dot(x.T,theta)
#      19     h = 1/1+ np.exp(-output)
#      20     return h
#
# ValueError: shapes (4,101) and (5,1) not aligned: 101 (dim 1) != 5 (dim 0)

# %% [markdown]
# ### back propogate

# %%
# Use a class for this model, it's good practice and condenses the code
class NNet3:
    def __init__(self, learning_rate=0.5, maxepochs=1e4, convergence_thres=1e-5, hidden_layer=4):
        self.learning_rate = learning_rate
        self.maxepochs = int(maxepochs)
        self.convergence_thres = 1e-5
        self.hidden_layer = int(hidden_layer)
        
    def _multiplecost(self, X, y):
        # feed through network
        l1, l2 = self._feedforward(X) 
        # compute error
        inner = y * np.log(l2) + (1-y) * np.log(1-l2)
        # negative of average error
        return -np.mean(inner)
    
    def _feedforward(self, X):
        # feedforward to the first layer
        l1 = sigmoid_activation(X.T, self.theta0).T
        # add a column of ones for bias term
        l1 = np.column_stack([np.ones(l1.shape[0]), l1])
        # activation units are then inputted to the output layer
        l2 = sigmoid_activation(l1.T, self.theta1)
        return l1, l2
    
    def predict(self, X):
        _, y = self._feedforward(X)
        return y
    
    def learn(self, X, y):
        nobs, ncols = X.shape
        self.theta0 = np.random.normal(0,0.01,size=(ncols,self.hidden_layer))
        self.theta1 = np.random.normal(0,0.01,size=(self.hidden_layer+1,1))
        
        self.costs = []
        cost = self._multiplecost(X, y)
        self.costs.append(cost)
        costprev = cost + self.convergence_thres+1  # set an inital costprev to past while loop
        counter = 0  # intialize a counter

        # Loop through until convergence
        for counter in range(self.maxepochs):
            # feedforward through network
            l1, l2 = self._feedforward(X)

            # Start Backpropagation
            # Compute gradients
            l2_delta = (y-l2) * l2 * (1-l2)
            l1_delta = l2_delta.T.dot(self.theta1.T) * l1 * (1-l1)

            # Update parameters by averaging gradients and multiplying by the learning rate
            self.theta1 += l1.T.dot(l2_delta.T) / nobs * self.learning_rate
            self.theta0 += X.T.dot(l1_delta)[:,1:] / nobs * self.learning_rate
            
            # Store costs and check for convergence
            counter += 1  # Count
            costprev = cost  # Store prev cost
            cost = self._multiplecost(X, y)  # get next cost
            self.costs.append(cost)
            if np.abs(costprev-cost) < self.convergence_thres and counter > 500:
                break

# Set a learning rate
learning_rate = 0.5
# Maximum number of iterations for gradient descent
maxepochs = 10000       
# Costs convergence threshold, ie. (prevcost - cost) > convergence_thres
convergence_thres = 0.00001  
# Number of hidden units
hidden_units = 4

# Initialize model 
model = NNet3(learning_rate=learning_rate, maxepochs=maxepochs,
              convergence_thres=convergence_thres, hidden_layer=hidden_units)
# Train model
model.learn(X, y)

# Plot costs
plt.plot(model.costs)
plt.title("Convergence of the Cost Function")
plt.ylabel("J($\Theta$)")
plt.xlabel("Iteration")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-35-991d80456280> in <module>()
#      74               convergence_thres=convergence_thres, hidden_layer=hidden_units)
#      75 # Train model
# ---> 76 model.learn(X, y)
#      77
#      78 # Plot costs
#
# <ipython-input-35-991d80456280> in learn(self, X, y)
#      34
#      35         self.costs = []
# ---> 36         cost = self._multiplecost(X, y)
#      37         self.costs.append(cost)
#      38         costprev = cost + self.convergence_thres+1  # set an inital costprev to past while loop
#
# <ipython-input-35-991d80456280> in _multiplecost(self, X, y)
#       9     def _multiplecost(self, X, y):
#      10         # feed through network
# ---> 11         l1, l2 = self._feedforward(X)
#      12         # compute error
#      13         inner = y * np.log(l2) + (1-y) * np.log(1-l2)
#
# <ipython-input-35-991d80456280> in _feedforward(self, X)
#      21         l1 = np.column_stack([np.ones(l1.shape[0]), l1])
#      22         # activation units are then inputted to the output layer
# ---> 23         l2 = sigmoid_activation(l1.T, self.theta1)
#      24         return l1, l2
#      25
#
# <ipython-input-20-3639b61e3cdf> in sigmoid_activation(x, theta)
#      16
#      17 def sigmoid_activation( x,theta ):
# ---> 18     output = np.dot(x.T,theta)
#      19     h = 1/1+ np.exp(-output)
#      20     return h
#
# ValueError: shapes (4,101) and (5,1) not aligned: 101 (dim 1) != 5 (dim 0)

# %%
# First 70 rows to X_train and y_train
# Last 30 rows to X_test and 
# First 70 rows to X_train and y_train
# Last 30 rows to X_test and y_test
X_train = X[:70]
y_train = y[:70]

X_test = X[-30:]
y_test = y[-30:]

# %%
from sklearn.metrics import roc_auc_score
# Set a learning rate
learning_rate = 0.5
# Maximum number of iterations for gradient descent
maxepochs = 10000       
# Costs convergence threshold, ie. (prevcost - cost) > convergence_thres
convergence_thres = 0.00001  
# Number of hidden units
hidden_units = 4

# Initialize model 
model = NNet3(learning_rate=learning_rate, maxepochs=maxepochs,
              convergence_thres=convergence_thres, hidden_layer=hidden_units)
model.learn(X_train, y_train)

yhat = model.predict(X_test)[0]

auc = roc_auc_score(y_test, yhat)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-37-09464009373d> in <module>()
#      12 model = NNet3(learning_rate=learning_rate, maxepochs=maxepochs,
#      13               convergence_thres=convergence_thres, hidden_layer=hidden_units)
# ---> 14 model.learn(X_train, y_train)
#      15
#      16 yhat = model.predict(X_test)[0]
#
# <ipython-input-35-991d80456280> in learn(self, X, y)
#      34
#      35         self.costs = []
# ---> 36         cost = self._multiplecost(X, y)
#      37         self.costs.append(cost)
#      38         costprev = cost + self.convergence_thres+1  # set an inital costprev to past while loop
#
# <ipython-input-35-991d80456280> in _multiplecost(self, X, y)
#       9     def _multiplecost(self, X, y):
#      10         # feed through network
# ---> 11         l1, l2 = self._feedforward(X)
#      12         # compute error
#      13         inner = y * np.log(l2) + (1-y) * np.log(1-l2)
#
# <ipython-input-35-991d80456280> in _feedforward(self, X)
#      21         l1 = np.column_stack([np.ones(l1.shape[0]), l1])
#      22         # activation units are then inputted to the output layer
# ---> 23         l2 = sigmoid_activation(l1.T, self.theta1)
#      24         return l1, l2
#      25
#
# <ipython-input-20-3639b61e3cdf> in sigmoid_activation(x, theta)
#      16
#      17 def sigmoid_activation( x,theta ):
# ---> 18     output = np.dot(x.T,theta)
#      19     h = 1/1+ np.exp(-output)
#      20     return h
#
# ValueError: shapes (4,71) and (5,1) not aligned: 71 (dim 1) != 5 (dim 0)
